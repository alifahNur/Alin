# %%
import numpy as np

mat = np.mat('1 -2;1 3')

#Original Matrix
print (mat)
print ('')
evalue, evect = np.linalg.eig(mat)

#Eigenvalue of thw solid matrix
print(evalue)
print('')

#Eigenvactors of the solid matrix
print(evect)
# Out:
# [[ 1 -2]
#  [ 1  3]]
#
# [2.+1.j 2.-1.j]
#
# [[ 0.81649658+0.j          0.81649658-0.j        ]
#  [-0.40824829-0.40824829j -0.40824829+0.40824829j]]
